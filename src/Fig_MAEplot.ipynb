# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Shirkvec = np.vectorize(HeBz2.Shirkov2024)
#       2 VVec = np.vectorize(HeBz2.V)
#
# NameError: name 'HeBz2' is not defined
